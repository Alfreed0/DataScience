# %% [markdown]
# Data Science

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Data/data_2019.csv')

# %%
df
# Out:
#             antigüedad cuartos cuartosdebaño estacionamiento  \
# 0      En construcción       3             3               2
# 1      En construcción       4             4               0
# 2                  NaN       1             1               3
# 3                    5       3             4               2
# 4                    5       4             4               0
# ...                ...     ...           ...             ...
# 10277  En construcción       4             4               2
# 10278                4       5             6               2
# 10279                6       3             4               2
# 10280                1       1             2               2
# 10281               14       4             0               1
#
#                                                  latlong  \
# 0      //maps.google.com/maps/api/staticmap?center=-2...
# 1      //maps.google.com/maps/api/staticmap?center=-2...
# 2      //maps.google.com/maps/api/staticmap?center=-2...
# ...

# %%
df.head(10)
# Out:
#         antigüedad cuartos cuartosdebaño estacionamiento  \
# 0  En construcción       3             3               2
# 1  En construcción       4             4               0
# 2              NaN       1             1               3
# 3                5       3             4               2
# 4                5       4             4               0
# 5               13       7             7              10
# 6              NaN     NaN           NaN             NaN
# 7                4       3             4               3
# 8                4       3             2               0
# 9              NaN       0             4              14
#
#                                              latlong metroscuadradostotales  \
# 0  //maps.google.com/maps/api/staticmap?center=-2...                  319m²
# 1  //maps.google.com/maps/api/staticmap?center=-2...                  410m²
# 2  //maps.google.com/maps/api/staticmap?center=-2...                   83m²
# ...

# %%
df.tail(15)
# Out:
#             antigüedad cuartos cuartosdebaño estacionamiento  \
# 10267                6       4             5               3
# 10268              NaN       0             1               3
# 10269                5       5             5               2
# 10270               10       4             6               4
# 10271                8       3             3               1
# 10272               10       4             4               2
# 10273                5       3             3               2
# 10274                4       3             2               1
# 10275               25       4             4               3
# 10276  En construcción       4             4               2
# 10277  En construcción       4             4               2
# 10278                4       5             6               2
# 10279                6       3             4               2
# 10280                1       1             2               2
# ...

# %%
df.shape
# Out:
# (10282, 10)

# %%
df['titulo']
# Out:
# 0                       Casa en Venta en Estancias del Rio
# 1                      Isla Mocoli Urb. Pacifica - 4 Dorm.
# 2        Vendo Casa de Estreno Urbanizacion Villa Itali...
# 3        Hermosa Casa en Venta Urb. Arcadia - 3 Dorm. 2...
# 4          Arrecife - Punta Mocoli Design By Jannina Cabal
#                                ...
# 10277            Proyecto Al Lago en La Peninsula - Mocoli
# 10278            Venta Villa Preciosa Super Amplia 5 Dorm.
# 10279    Oportunidad Moderna Casa en Via a La Costa Urb...
# 10280    Venta C Celeste Villa 1 Sola Planta 1 Dormitor...
# 10281                    Villa X Uess 4 Dormitorio Estudio
# Name: titulo, Length: 10282, dtype: object

# %%
df['estacionamiento'].dtype
# Out:
# dtype('O')

# %%
df.dtypes
# Out:
# antigüedad                object
# cuartos                   object
# cuartosdebaño             object
# estacionamiento           object
# latlong                   object
# metroscuadradostotales    object
# precio                    object
# publicado                 object
# tipodevendedor            object
# titulo                    object
# dtype: object
