# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(
    '../Data/201703_EnemduBDD_15anios.csv',
    sep=';',
    decimal=',',
    keep_default_na=False,
    na_values= [' ']
    )

# %%
df
# Out:
#        area  ciudad  zona  sector  panelm  vivienda  hogar  p01  p02  p03  \
# 0         1   10150     1       3     112         1      1    1    1   54
# 1         1   10150     1       3     112         1      1    2    2   53
# 2         1   10150     1       3     112         1      1    3    2   15
# 3         1   10150     1       3     112         2      1    1    2   51
# 4         1   10150     1       3     112         2      1    2    1   47
# ...     ...     ...   ...     ...     ...       ...    ...  ...  ...  ...
# 59237     2  900451   999       7     182         3      1    4    2   22
# 59238     2  900451   999       7     182         3      1    5    2   37
# 59239     2  900451   999       7     182         3      1    6    1   13
# 59240     2  900451   999       7     182         3      1    7    2    4
# 59241     2  900451   999       7     182         4      1    1    2   74
#
#        ...  desem  desemab  desemoc desem1 desem2 pein menor10 menor15  \
# ...

# %%
df.dtypes
# Out:
# area         int64
# ciudad       int64
# zona         int64
# sector       int64
# panelm       int64
#             ...
# pein       float64
# menor10    float64
# menor15    float64
# pobla10    float64
# pobla15    float64
# Length: 185, dtype: object

# %%
df['ingpc']
# Out:
# 0        494.000000
# 1        494.000000
# 2        494.000000
# 3        352.000000
# 4        352.000000
#             ...
# 59237    368.142857
# 59238    368.142857
# 59239    368.142857
# 59240    368.142857
# 59241    300.000000
# Name: ingpc, Length: 59242, dtype: float64

# %%
df_spp = pd.read_spss(
    '../Data/201703_EnemduBDD_15anios.sav'
)

# %%
df_spp
# Out:
#          area    ciudad zona sector    panelm                     vivienda  \
# 0      Urbana   10150.0  001    003  Panel K2                 Vivienda Uno
# 1      Urbana   10150.0  001    003  Panel K2                 Vivienda Uno
# 2      Urbana   10150.0  001    003  Panel K2                 Vivienda Uno
# 3      Urbana   10150.0  001    003  Panel K2                 Vivienda Dos
# 4      Urbana   10150.0  001    003  Panel K2                 Vivienda Dos
# ...       ...       ...  ...    ...       ...                          ...
# 59237   Rural  900451.0  999    007  Panel R2                Vivienda Tres
# 59238   Rural  900451.0  999    007  Panel R2                Vivienda Tres
# 59239   Rural  900451.0  999    007  Panel R2                Vivienda Tres
# 59240   Rural  900451.0  999    007  Panel R2                Vivienda Tres
# 59241   Rural  900451.0  999    007  Panel R2  Vivienda Cuatro (reemplazo)
#
# ...

# %%
df_spp.dtypes
# Out:
# area       category
# ciudad      float64
# zona         object
# sector       object
# panelm     category
#              ...
# pein       category
# menor10    category
# menor15    category
# pobla10    category
# pobla15    category
# Length: 185, dtype: object

# %%
df_spp['ingpc']
# Out:
# 0        494.000000
# 1        494.000000
# 2        494.000000
# 3        352.000000
# 4        352.000000
#             ...
# 59237    368.142857
# 59238    368.142857
# 59239    368.142857
# 59240    368.142857
# 59241    300.000000
# Name: ingpc, Length: 59242, dtype: float64

# %%
df_spp.shape
# Out:
# (59242, 185)
