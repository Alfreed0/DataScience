# %% [markdown]
# Limpieza y manipulacion de datos

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_spss(
    '../Data/201703_EnemduBDD_viviendahogar.sav'
)

# %%
df.columns
# Out:
# Index(['area', 'ciudad', 'zona', 'sector', 'panelm', 'vivienda', 'hogar',
#        'vi01', 'vi02', 'vi03a', 'vi03b', 'vi04a', 'vi04b', 'vi05a', 'vi05b',
#        'vi06', 'vi07', 'vi07a', 'vi08', 'vi09', 'vi10', 'vi10a', 'vi11',
#        'vi12', 'vi13', 'vi14', 'plan_muestreo', 'fexp'],
#       dtype='object')

# %%
df.dtypes
# Out:
# area             category
# ciudad            float64
# zona               object
# sector             object
# panelm           category
# vivienda         category
# hogar            category
# vi01             category
# vi02             category
# vi03a            category
# vi03b            category
# vi04a            category
# vi04b            category
# vi05a            category
# vi05b            category
# vi06             category
# vi07             category
# vi07a            category
# vi08             category
# vi09             category
# vi10             category
# vi10a            category
# vi11             category
# vi12             category
# vi13             category
# vi14             category
# plan_muestreo      object
# fexp              float64
# dtype: object

# %%
ser = df.isnull().sum(axis=1)

# %%
(ser > 0).sum()
# Out:
# 15107

# %%
ser
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 15824    1
# 15825    1
# 15826    1
# 15827    1
# 15828    1
# Length: 15829, dtype: int64

# %%
df.isnull().any(axis=1)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 15824    True
# 15825    True
# 15826    True
# 15827    True
# 15828    True
# Length: 15829, dtype: bool

# %%
df.isnull().any(axis=1).sum()
# Out:
# 15107

# %%
df.isnull().all(axis=1)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15824    False
# 15825    False
# 15826    False
# 15827    False
# 15828    False
# Length: 15829, dtype: bool

# %%
df.isnull().all(axis=1).sum()
# Out:
# 0

# %%
df['area'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15824    False
# 15825    False
# 15826    False
# 15827    False
# 15828    False
# Name: area, Length: 15829, dtype: bool

# %%
df['area'].isnull().sum()
# Out:
# 0

# %%
df['ciudad'].isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15824    False
# 15825    False
# 15826    False
# 15827    False
# 15828    False
# Name: ciudad, Length: 15829, dtype: bool

# %%
df['ciudad'].notnull().sum()
# Out:
# 15829

# %%
df.index
# Out:
# RangeIndex(start=0, stop=15829, step=1)

# %%
df.iloc[:5, :3]
# Out:
#      area   ciudad zona
# 0  Urbana  10150.0  001
# 1  Urbana  10150.0  001
# 2  Urbana  10150.0  001
# 3  Urbana  10150.0  001
# 4  Urbana  10150.0  001

# %%
df.iloc[:, -3:]
# Out:
#                              vi14 plan_muestreo        fexp
# 0      Propia y totalmente pagada          1013   78.141584
# 1                     En arriendo          1013   78.141584
# 2        Propia y la está pagando          1013   78.141584
# 3      Propia y totalmente pagada          1013   78.141584
# 4                     En arriendo          1013   78.141584
# ...                           ...           ...         ...
# 15824  Propia y totalmente pagada           290  177.514885
# 15825  Propia y totalmente pagada           290  177.514885
# 15826      Recibida por servicios           290  177.514885
# 15827  Propia y totalmente pagada           290  177.514885
# 15828  Propia y totalmente pagada           290  177.514885
#
# [15829 rows x 3 columns]

# %%
df.iloc[:,[0, 3, 9]]
# Out:
#          area sector             vi03a
# 0      Urbana    003              Teja
# 1      Urbana    003  Asbesto, eternit
# 2      Urbana    003  Asbesto, eternit
# 3      Urbana    003              Teja
# 4      Urbana    003              Teja
# ...       ...    ...               ...
# 15824   Rural    007              Zinc
# 15825   Rural    007              Zinc
# 15826   Rural    007              Zinc
# 15827   Rural    007              Zinc
# 15828   Rural    007              Zinc
#
# [15829 rows x 3 columns]

# %%
df_sliced = df.loc[:,['area', 'sector']]

# %%
df_sliced.isnull().all(axis=1).sum()
# Out:
# 0

# %%
df.iloc[3, :]
# Out:
# area                                                Urbana
# ciudad                                             10150.0
# zona                                                   001
# sector                                                 003
# panelm                                            Panel L2
# vivienda                                      Vivienda Uno
# hogar                                            Hogar Uno
# vi01             Carretera, calle pavimentada o adoquinada
# vi02                                          Casa o villa
# vi03a                                                 Teja
# vi03b                                              Regular
# vi04a                             Tabla, tablón no tratado
# vi04b                                                Bueno
# vi05a                           Hormigón, bloque, ladrillo
# vi05b                                                Bueno
# vi06                                                   8.0
# ...

# %%
df.iloc[3, 5]
# Out:
# 'Vivienda Uno'

# %%
df.loc[:, 'area']
# Out:
# 0        Urbana
# 1        Urbana
# 2        Urbana
# 3        Urbana
# 4        Urbana
#           ...
# 15824     Rural
# 15825     Rural
# 15826     Rural
# 15827     Rural
# 15828     Rural
# Name: area, Length: 15829, dtype: category
# Categories (2, object): ['Rural', 'Urbana']

# %%
df.loc[:, 'area' : 'sector']
# Out:
#          area    ciudad zona sector
# 0      Urbana   10150.0  001    003
# 1      Urbana   10150.0  001    003
# 2      Urbana   10150.0  001    003
# 3      Urbana   10150.0  001    003
# 4      Urbana   10150.0  001    003
# ...       ...       ...  ...    ...
# 15824   Rural  900451.0  999    007
# 15825   Rural  900451.0  999    007
# 15826   Rural  900451.0  999    007
# 15827   Rural  900451.0  999    007
# 15828   Rural  900451.0  999    007
#
# [15829 rows x 4 columns]

# %%
df.loc[:, ['ciudad', 'sector']]
# Out:
#          ciudad sector
# 0       10150.0    003
# 1       10150.0    003
# 2       10150.0    003
# 3       10150.0    003
# 4       10150.0    003
# ...         ...    ...
# 15824  900451.0    007
# 15825  900451.0    007
# 15826  900451.0    007
# 15827  900451.0    007
# 15828  900451.0    007
#
# [15829 rows x 2 columns]

# %%
new_df = pd.read_csv(
    '../Data/data_2019.csv'
)

# %%
new_df
# Out:
#             antigüedad cuartos cuartosdebaño estacionamiento  \
# 0      En construcción       3             3               2
# 1      En construcción       4             4               0
# 2                  NaN       1             1               3
# 3                    5       3             4               2
# 4                    5       4             4               0
# ...                ...     ...           ...             ...
# 10277  En construcción       4             4               2
# 10278                4       5             6               2
# 10279                6       3             4               2
# 10280                1       1             2               2
# 10281               14       4             0               1
#
#                                                  latlong  \
# 0      //maps.google.com/maps/api/staticmap?center=-2...
# 1      //maps.google.com/maps/api/staticmap?center=-2...
# 2      //maps.google.com/maps/api/staticmap?center=-2...
# ...

# %%
new_df.dropna(subset= ['titulo', 'metroscuadradostotales', 'precio', 'latlong'], inplace=True)

# %%
new_df
# Out:
#             antigüedad  cuartos  cuartosdebaño  estacionamiento  \
# 5130        antigüedad  cuartos  cuartosdebaño  estacionamiento
# 5131                 5        4              4                0
# 5132        A estrenar        4              3                2
# 5133                20        4              4                3
# 5134   En construcción        0              4                2
# ...                ...      ...            ...              ...
# 10277  En construcción        4              4                2
# 10278                4        5              6                2
# 10279                6        3              4                2
# 10280                1        1              2                2
# 10281               14        4              0                1
#
#                                                  latlong  \
# 5130                                             latlong
# 5131   //maps.google.com/maps/api/staticmap?center=-2...
# ...

# %%
new_df.reset_index()
# Out:
#       index       antigüedad  cuartos  cuartosdebaño  estacionamiento  \
# 0      5130       antigüedad  cuartos  cuartosdebaño  estacionamiento
# 1      5131                5        4              4                0
# 2      5132       A estrenar        4              3                2
# 3      5133               20        4              4                3
# 4      5134  En construcción        0              4                2
# ...     ...              ...      ...            ...              ...
# 5016  10277  En construcción        4              4                2
# 5017  10278                4        5              6                2
# 5018  10279                6        3              4                2
# 5019  10280                1        1              2                2
# 5020  10281               14        4              0                1
#
#                                                 latlong  \
# 0                                               latlong
# ...

# %%
new_df.reset_index(drop=True)
# Out:
#            antigüedad  cuartos  cuartosdebaño  estacionamiento  \
# 0          antigüedad  cuartos  cuartosdebaño  estacionamiento
# 1                   5        4              4                0
# 2          A estrenar        4              3                2
# 3                  20        4              4                3
# 4     En construcción        0              4                2
# ...               ...      ...            ...              ...
# 5016  En construcción        4              4                2
# 5017                4        5              6                2
# 5018                6        3              4                2
# 5019                1        1              2                2
# 5020               14        4              0                1
#
#                                                 latlong  \
# 0                                               latlong
# 1     //maps.google.com/maps/api/staticmap?center=-2...
# ...

# %%
new_df.reset_index(drop=True, inplace=True)

# %%
new_df.head()
# Out:
#         antigüedad  cuartos  cuartosdebaño  estacionamiento  \
# 0       antigüedad  cuartos  cuartosdebaño  estacionamiento
# 1                5        4              4                0
# 2       A estrenar        4              3                2
# 3               20        4              4                3
# 4  En construcción        0              4                2
#
#                                              latlong  metroscuadradostotales  \
# 0                                            latlong  metroscuadradostotales
# 1  //maps.google.com/maps/api/staticmap?center=-2...                   480m²
# 2  //maps.google.com/maps/api/staticmap?center=-2...                   400m²
# 3  //maps.google.com/maps/api/staticmap?center=-2...                   244m²
# 4  //maps.google.com/maps/api/staticmap?center=-2...                     1m²
#
#         precio  publicado  tipodevendedor  \
# 0       precio  publicado  tipodevendedor
# 1  USD 565.000        NaN             NaN
# ...

# %%
new_df.drop(columns=["antigüedad", "cuartos", "cuartosdebaño", "estacionamiento", "publicado", "tipodevendedor"], inplace=True)

# %%
new_df
# Out:
#                                                 latlong  \
# 0                                               latlong
# 1     //maps.google.com/maps/api/staticmap?center=-2...
# 2     //maps.google.com/maps/api/staticmap?center=-2...
# 3     //maps.google.com/maps/api/staticmap?center=-2...
# 4     //maps.google.com/maps/api/staticmap?center=-2...
# ...                                                 ...
# 5016  //maps.google.com/maps/api/staticmap?center=nu...
# 5017  //maps.google.com/maps/api/staticmap?center=nu...
# 5018  //maps.google.com/maps/api/staticmap?center=-2...
# 5019  //maps.google.com/maps/api/staticmap?center=nu...
# 5020  //maps.google.com/maps/api/staticmap?center=nu...
#
#       metroscuadradostotales       precio  \
# 0     metroscuadradostotales       precio
# 1                      480m²  USD 565.000
# 2                      400m²  USD 370.000
# 3                      244m²  USD 140.000
# 4                        1m²  USD 259.000
# ...

# %% [markdown]
# Clase del jueves

# %%
new_df['metroscuadradostotales'] != 'metroscuadradostotales'
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 5016     True
# 5017     True
# 5018     True
# 5019     True
# 5020     True
# Name: metroscuadradostotales, Length: 5021, dtype: bool

# %%
new_df['metroscuadradostotales'].unique()
# Out:
# array(['metroscuadradostotales', '480m²', '400m²', '244m²', '1m²',
#        '245m²', '1090m²', '580m²', '505m²', '240m²', '170m²', '319m²',
#        '593m²', '186m²', '570m²', '189m²', '461m²', '83m²', '405m²',
#        '410m²', '600m²', '767m²', '250m²', '180m²', '550m²', '160m²',
#        '2000m²', '105m²', '103m²', '120m²', '96m²', '268m²', '230m²',
#        '175m²', '104m²', '546m²', '203m²', '200m²', '1460m²', '144m²',
#        '540m²', '470m²', '251m²', '740m²', '530m²', '290m²', '122m²',
#        '72m²', '90m²', '406m²', '127m²', '337m²', '453m²', '423m²',
#        '502m²', '420m²', '101m²', '243m²', '56m²', '456m²', '138m²',
#        '523m²', '225m²', '316m²', '1088m²', '263m²', '132m²', '112m²',
#        '324m²', '854m²', '113m²', '156m²', '258m²', '147m²', '255m²',
#        '297m²', '330m²', '1700m²', '364m²', '450m²', '276m²', '142m²',
#        '396m²', '210m²', '500m²', '472m²', '495m²', '238m²', '267m²',
# ...

# %%
new_df = new_df.loc[(new_df['metroscuadradostotales'] != 'metroscuadradostotales') & (new_df['precio'] != 'Consultar precio')].reset_index(drop=True)

# %%
new_df
# Out:
#                                                 latlong  \
# 0     //maps.google.com/maps/api/staticmap?center=-2...
# 1     //maps.google.com/maps/api/staticmap?center=-2...
# 2     //maps.google.com/maps/api/staticmap?center=-2...
# 3     //maps.google.com/maps/api/staticmap?center=-2...
# 4     //maps.google.com/maps/api/staticmap?center=-2...
# ...                                                 ...
# 5012  //maps.google.com/maps/api/staticmap?center=nu...
# 5013  //maps.google.com/maps/api/staticmap?center=nu...
# 5014  //maps.google.com/maps/api/staticmap?center=-2...
# 5015  //maps.google.com/maps/api/staticmap?center=nu...
# 5016  //maps.google.com/maps/api/staticmap?center=nu...
#
#      metroscuadradostotales       precio  \
# 0                     480m²  USD 565.000
# 1                     400m²  USD 370.000
# 2                     244m²  USD 140.000
# 3                       1m²  USD 259.000
# 4                     245m²  USD 245.000
# ...

# %%
new_df['titulo'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/alfreed0/My Drive/IPYNBs/Notebooks/clean&edit.ipynb Cell 43 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/alfreed0/My%20Drive/IPYNBs/Notebooks/clean%26edit.ipynb#X60sZmlsZQ%3D%3D?line=0'>1</a> new_df['titulo'].astype('float')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# ...

# %%
new_df['metroscuadradostotales'] = new_df['metroscuadradostotales'].str.replace('m²', '')

# %%
new_df['metroscuadradostotales'] = new_df['metroscuadradostotales'].astype('int64')

# %%
new_df['metroscuadradostotales']
# Out:
# 0       480
# 1       400
# 2       244
# 3         1
# 4       245
#        ...
# 5012    660
# 5013    700
# 5014    350
# 5015    256
# 5016    230
# Name: metroscuadradostotales, Length: 5017, dtype: int64

# %%
new_df['precio'] = new_df['precio'].str.replace('USD', '').str.replace('.', '',regex=False).astype('int64')

# %%
new_df
# Out:
#                                                 latlong  \
# 0     //maps.google.com/maps/api/staticmap?center=-2...
# 1     //maps.google.com/maps/api/staticmap?center=-2...
# 2     //maps.google.com/maps/api/staticmap?center=-2...
# 3     //maps.google.com/maps/api/staticmap?center=-2...
# 4     //maps.google.com/maps/api/staticmap?center=-2...
# ...                                                 ...
# 5012  //maps.google.com/maps/api/staticmap?center=nu...
# 5013  //maps.google.com/maps/api/staticmap?center=nu...
# 5014  //maps.google.com/maps/api/staticmap?center=-2...
# 5015  //maps.google.com/maps/api/staticmap?center=nu...
# 5016  //maps.google.com/maps/api/staticmap?center=nu...
#
#       metroscuadradostotales  precio  \
# 0                        480  565000
# 1                        400  370000
# 2                        244  140000
# 3                          1  259000
# 4                        245  245000
# ...                      ...     ...
# ...

# %%
new_df.iloc[5010,0]
# Out:
# '//maps.google.com/maps/api/staticmap?center=-2.1561673,-79.90530819999998&zoom=16&channel=PV&size=780x456&sensor=true&scale=2&key=AIzaSyBZ0l4aIUv2yia6kSFP_hc3Q4Z_lQ0Nl5w&signature=Z2LzDhQQlhMkf3GFEV3OTVJyDAU='

# %%
new_df[['lat', 'long']] = new_df['latlong'].str.split('=', expand=True)[1].str.split(',', expand=True)

# %%
new_df
# Out:
#                                                 latlong  \
# 0     //maps.google.com/maps/api/staticmap?center=-2...
# 1     //maps.google.com/maps/api/staticmap?center=-2...
# 2     //maps.google.com/maps/api/staticmap?center=-2...
# 3     //maps.google.com/maps/api/staticmap?center=-2...
# 4     //maps.google.com/maps/api/staticmap?center=-2...
# ...                                                 ...
# 5012  //maps.google.com/maps/api/staticmap?center=nu...
# 5013  //maps.google.com/maps/api/staticmap?center=nu...
# 5014  //maps.google.com/maps/api/staticmap?center=-2...
# 5015  //maps.google.com/maps/api/staticmap?center=nu...
# 5016  //maps.google.com/maps/api/staticmap?center=nu...
#
#       metroscuadradostotales  precio  \
# 0                        480  565000
# 1                        400  370000
# 2                        244  140000
# 3                          1  259000
# 4                        245  245000
# ...                      ...     ...
# ...

# %%
new_df['long'] = new_df['long'].str.replace('&zoom', '')

# %%
new_df.columns
# Out:
# Index(['latlong', 'metroscuadradostotales', 'precio', 'titulo', 'lat', 'long'], dtype='object')

# %%
new_df.columns = ['locacion', 'metroscuadradostotales', 'precio', 'titulo', 'latitud', 'longitud']

# %%
new_df = new_df.loc[(new_df['latitud'] != 'null') & (new_df['longitud'] != 'null')].reset_index(drop=True)

# %%
new_df
# Out:
#                                                locacion  \
# 0     //maps.google.com/maps/api/staticmap?center=-2...
# 1     //maps.google.com/maps/api/staticmap?center=-2...
# 2     //maps.google.com/maps/api/staticmap?center=-2...
# 3     //maps.google.com/maps/api/staticmap?center=-2...
# 4     //maps.google.com/maps/api/staticmap?center=-2...
# ...                                                 ...
# 4079  //maps.google.com/maps/api/staticmap?center=-2...
# 4080  //maps.google.com/maps/api/staticmap?center=-2...
# 4081  //maps.google.com/maps/api/staticmap?center=-2...
# 4082  //maps.google.com/maps/api/staticmap?center=-2...
# 4083  //maps.google.com/maps/api/staticmap?center=-2...
#
#       metroscuadradostotales  precio  \
# 0                        480  565000
# 1                        400  370000
# 2                        244  140000
# 3                          1  259000
# 4                        245  245000
# ...                      ...     ...
# ...

# %%
new_df['latitud'] = new_df['latitud'].astype('float64')
new_df['longitud'] = new_df['longitud'].astype('float64')

# %%
new_df.dtypes
# Out:
# locacion                   object
# metroscuadradostotales      int64
# precio                      int64
# titulo                     object
# latitud                   float64
# longitud                  float64
# dtype: object

# %%
new_df['latitud'].str.contains('null') #Alternativa al != en la serie booleana
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/alfreed0/My Drive/IPYNBs/Notebooks/clean&edit.ipynb Cell 59 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/alfreed0/My%20Drive/IPYNBs/Notebooks/clean%26edit.ipynb#Y112sZmlsZQ%3D%3D?line=0'>1</a> new_df['latitud'].str.contains('null')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
# ...

# %%
new_df.drop(columns=['locacion'], inplace=True)

# %%
new_df
# Out:
#       metroscuadradostotales  precio  \
# 0                        480  565000
# 1                        400  370000
# 2                        244  140000
# 3                          1  259000
# 4                        245  245000
# ...                      ...     ...
# 4079                     400  480000
# 4080                     250  270000
# 4081                     136  120000
# 4082                     560  220000
# 4083                     350  380000
#
#                                                  titulo   latitud   longitud
# 0       Arrecife - Punta Mocoli Design By Jannina Cabal -2.115345 -79.856163
# 1          Vendo Casa Moderna de Estreno en Isla Mocoli -2.102443 -79.867073
# 2     Venta de Casa Cdla. del Biess Remodelada - Sec... -2.230328 -79.902163
# 3     Se Vende Proyecto en Isla Celeste Reserva Solo... -2.071614 -79.842065
# 4     Isla Celeste 243 m² Const y 225 m² Terreno Her... -2.079416 -79.837993
# ...

# %%
new_df['preciomt2'] = new_df['precio'] / new_df['metroscuadradostotales']

# %%
new_df
# Out:
#       metroscuadradostotales  precio  \
# 0                        480  565000
# 1                        400  370000
# 2                        244  140000
# 3                          1  259000
# 4                        245  245000
# ...                      ...     ...
# 4079                     400  480000
# 4080                     250  270000
# 4081                     136  120000
# 4082                     560  220000
# 4083                     350  380000
#
#                                                  titulo   latitud   longitud  \
# 0       Arrecife - Punta Mocoli Design By Jannina Cabal -2.115345 -79.856163
# 1          Vendo Casa Moderna de Estreno en Isla Mocoli -2.102443 -79.867073
# 2     Venta de Casa Cdla. del Biess Remodelada - Sec... -2.230328 -79.902163
# 3     Se Vende Proyecto en Isla Celeste Reserva Solo... -2.071614 -79.842065
# 4     Isla Celeste 243 m² Const y 225 m² Terreno Her... -2.079416 -79.837993
# ...

# %%
new_df.dtypes
# Out:
# metroscuadradostotales      int64
# precio                      int64
# titulo                     object
# latitud                   float64
# longitud                  float64
# preciomt2                 float64
# dtype: object

# %% [markdown]
# Tarea: Nuevo data set donde debemos dejar las mismas columnas y los procesos de limpieza
# head()
# dtypes
# shape

# %%
new_df.drop_duplicates(subset=['latitud', 'longitud', 'metroscuadradostotales', 'precio'], inplace=True)

# %%
new_df
# Out:
#       metroscuadradostotales  precio  \
# 0                        480  565000
# 1                        400  370000
# 2                        244  140000
# 3                          1  259000
# 4                        245  245000
# ...                      ...     ...
# 3855                     400  480000
# 3856                     250  270000
# 3857                     136  120000
# 3858                     560  220000
# 3859                     350  380000
#
#                                                  titulo   latitud   longitud  \
# 0       Arrecife - Punta Mocoli Design By Jannina Cabal -2.115345 -79.856163
# 1          Vendo Casa Moderna de Estreno en Isla Mocoli -2.102443 -79.867073
# 2     Venta de Casa Cdla. del Biess Remodelada - Sec... -2.230328 -79.902163
# 3     Se Vende Proyecto en Isla Celeste Reserva Solo... -2.071614 -79.842065
# 4     Isla Celeste 243 m² Const y 225 m² Terreno Her... -2.079416 -79.837993
# ...

# %%
new_df.reset_index(drop=True, inplace=True)

# %%
def categorize(row):
    if row['preciomt2'] > 1000:
        return 'A'
    elif row['preciomt2'] > 500:
        return 'B'
    else:
        return 'C'

# %%
new_df['categoria'] = new_df.apply(categorize, axis=1, result_type='expand')

# %%
new_df.to_csv('../Output/data_2019_clean.csv', index=False)
